# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sympy as sp

# %%
import math

# %%
math.log(3)
# Out:
# 1.0986122886681098

# %%
math.exp(3)  ##e的x次方
# Out:
# 20.085536923187668

# %%
x = np.linspace(-10,10,100)
y = np.cos(x) + np.sin(y)

# %%
plt.plot(x,y)

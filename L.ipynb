# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.linspace(0,5,100)

# %%
y = 2*x + 7

# %%
plt.scatter(x,y)

# %%
y = 2*x +7 + 1* np.random.randn(100)

# %%
plt.scatter(x,y)
plt.plot(x, 2*x + 7, 'b')
